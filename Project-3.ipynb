# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Sonar.csv")
df
# Out:
#          V1      V2      V3      V4      V5      V6      V7      V8      V9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      208 non-null    float64
#  1   V2      208 non-null    float64
#  2   V3      208 non-null    float64
#  3   V4      208 non-null    float64
#  4   V5      208 non-null    float64
#  5   V6      208 non-null    float64
#  6   V7      208 non-null    float64
#  7   V8      208 non-null    float64
#  8   V9      208 non-null    float64
#  9   V10     208 non-null    float64
#  10  V11     208 non-null    float64
#  11  V12     208 non-null    float64
#  12  V13     208 non-null    float64
#  13  V14     208 non-null    float64
#  14  V15     208 non-null    float64
#  15  V16     208 non-null    float64
#  16  V17     208 non-null    float64
#  17  V18     208 non-null    float64
#  18  V19     208 non-null    float64
#  19  V20     208 non-null    float64
# ...

# %% [markdown]
# # Summary Statistic

# %%
df.describe()
# Out:
#                V1          V2          V3          V4          V5          V6  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                V7          V8          V9         V10  ...         V52  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.013420
# ...

# %% [markdown]
# 1. the mean is more than 50%(median) in all column.
# 2. there is alarge diffrence between 75% and max. in V7,V8,V9,V10.
# 3. The 1 and 2 observation suggest that there are extreme outliers present in these columns

# %% [markdown]
# # Data Visualization

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# so there is no null value are shown in heatmap.

# %% [markdown]
# # EDA

# %% [markdown]
# # To check correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# V1     1.000000  0.735896  0.571537  0.491438  0.344797  0.238921  0.260815
# V2     0.735896  1.000000  0.779916  0.606684  0.419669  0.332329  0.279040
# V3     0.571537  0.779916  1.000000  0.781786  0.546141  0.346275  0.190434
# V4     0.491438  0.606684  0.781786  1.000000  0.726943  0.352805  0.246440
# V5     0.344797  0.419669  0.546141  0.726943  1.000000  0.597053  0.335422
# ...         ...       ...       ...       ...       ...       ...       ...
# V57    0.313725  0.280341  0.380819  0.340254  0.219395  0.161333  0.186324
# V58    0.368132  0.353042  0.334108  0.344865  0.238793  0.203986  0.242646
# V59    0.357116  0.352200  0.425047  0.420266  0.290982  0.220573  0.183578
# V60    0.347078  0.358761  0.373948  0.400626  0.253710  0.178158  0.222493
# Class -0.271694 -0.231238 -0.192195 -0.250638 -0.222232 -0.132327 -0.114748
#
# ...

# %%
df.skew()
# Out:
# V1       2.131088
# V2       2.155644
# V3       2.652518
# V4       3.401697
# V5       2.018141
#            ...
# V57      1.653090
# V58      2.098330
# V59      1.737506
# V60      2.775754
# Class    0.135903
# Length: 61, dtype: float64

# %%
df['V7'].plot.box()

# %%
df['V8'].plot.box()

# %%
df['V9'].plot.box()

# %%
df['V10'].plot.box()

# %% [markdown]
# # To Check Skewness

# %%
sns.distplot(df['V1'])

# %%
sns.distplot(df['V9'])

# %% [markdown]
# # Bivariate Analysis

# %%
plt.scatter(df['Class'],df['V1'])

# %%
df.drop('V1' , axis=1 , inplace=True)

# %%
df.head()
# Out:
#        V2      V3      V4      V5      V6      V7      V8      V9     V10  \
# 0  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  0.2111
# 1  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337  0.2872
# 2  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598  0.6194
# 3  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598  0.1264
# 4  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564  0.4459
#
#       V11  ...     V52     V53     V54     V55     V56     V57     V58  \
# 0  0.1609  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.4918  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6333  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.0881  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4152  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#       V59     V60  Class
# 0  0.0090  0.0032      1
# 1  0.0052  0.0044      1
# ...

# %%
df.shape
# Out:
# (208, 60)

# %% [markdown]
# # Removing Outlier

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.04064823, 0.02692565, 0.71510513, ..., 0.17167808, 0.65894689,
#         1.06973356],
#        [0.42163039, 1.05561832, 0.32333027, ..., 0.44455424, 0.41985233,
#         1.06973356],
#        [0.60106749, 1.72340448, 1.1721758 , ..., 0.25276128, 0.25758223,
#         1.06973356],
#        ...,
#        [0.16007801, 0.67384349, 0.53197856, ..., 0.03913824, 0.67887143,
#         0.93481221],
#        [0.09539176, 0.13480381, 0.14882142, ..., 0.70402047, 0.34015415,
#         0.93481221],
#        [0.06497869, 0.78861924, 0.57506716, ..., 0.29860448, 0.99479044,
#         0.93481221]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  2,   2,   2,   2,   2,   3,   3,   5,   5,  19,  19,  20,  21,
#         22,  22,  22,  22,  22,  22,  22,  22,  33,  44,  44,  44,  65,
#         85,  85,  87,  91,  91,  97,  97,  98,  98,  98,  98,  98, 101,
#        101, 105, 111, 111, 111, 112, 127, 127, 127, 129, 129, 132, 132,
#        133, 133, 133, 134, 134, 134, 135, 135, 135, 135, 136, 136, 136,
#        137, 137, 138, 138, 138, 140, 140, 140, 140, 140, 141, 141, 142,
#        142, 142, 143, 143, 143, 144, 145, 145, 146, 146, 146, 146, 146,
#        146, 146, 146, 147, 147, 147, 147, 147, 147, 147, 147, 161, 184,
#        186, 186, 186], dtype=int64), array([ 7,  8,  9, 10, 55, 37, 38, 12, 13,  3,  6,  4, 36, 37, 38, 39, 40,
#        45, 46, 47, 48, 48, 38, 41, 42, 57,  0,  1, 55,  4,  5, 57, 58,  0,
#         1,  2,  3, 58, 11, 56, 54,  1,  2,  3, 56, 12, 53, 56, 11, 52,  6,
#         7,  7,  8, 51,  5,  6,  7,  6,  7, 52, 54,  6,  7, 50,  8,  9,  1,
# ...

# %%
z[2][1]
# Out:
# 1.7234044836233406

# %%
z[2][2]
# Out:
# 1.1721758008823309

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#          V2      V3      V4      V5      V6      V7      V8      V9     V10  \
# 0    0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  0.2111
# 1    0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337  0.2872
# 4    0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564  0.4459
# 6    0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083  0.3513
# 7    0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465  0.2838
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328  0.2684
# 204  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030  0.2154
# 205  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258  0.2529
# 206  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945  0.2354
# 207  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843  0.2354
#
# ...

# %%
df.shape
# Out:
# (208, 60)

# %%
df_new.shape
# Out:
# (169, 60)
