# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('temp.dataset.txt')

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
pd.set_option('display.max_columns',None) # to view all the columns

# %%
#Checking the shape of the dataset
df.shape
# Out:
# (7752, 25)

# %%
#Cheking column names
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
#Converting date column to datetime type as it was of object type 
df['Date']=pd.to_datetime(df['Date'])

# %%
#Checking null values
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
#Check mean, standard deviation and medain of the data
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.673499         22.089739     5.678705    37.266753
# 50%           29.703426         23.760199     6.547470    56.865482
# 75%           31.710450         25.152909     8.032276    84.223616
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1    LDAPS_CC2    LDAPS_CC3    LDAPS_CC4   LDAPS_PPT1  \
# count  7677.000000  7677.000000  7677.000000  7677.000000  7677.000000
# mean      0.368774     0.356080     0.318404     0.299191     0.591995
# std       0.262458     0.258061     0.250362     0.254348     1.945768
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.146654     0.140615     0.101388     0.081532     0.000000
# 50%       0.315697     0.312421     0.262555     0.227664     0.000000
# 75%       0.575489     0.558694     0.496703     0.499489     0.052525
# max       0.967277     0.968353     0.983789     0.974710    23.701544
#
#         LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat          lon  \
# count  7677.000000  7677.000000  7677.000000  7752.000000  7752.000000
# mean      0.485003     0.278200     0.269407    37.544722   126.991397
# std       1.762807     1.161809     1.206214     0.050352     0.079435
# min       0.000000     0.000000     0.000000    37.456200   126.826000
# 25%       0.000000     0.000000     0.000000    37.510200   126.937000
# 50%       0.000000     0.000000     0.000000    37.550700   126.995000
# 75%       0.018364     0.007896     0.000041    37.577600   127.042000
# max      21.621661    15.841235    16.655469    37.645000   127.135000
#
#                DEM        Slope  Solar radiation    Next_Tmax    Next_Tmin
# count  7752.000000  7752.000000      7752.000000  7725.000000  7725.000000
# mean     61.867972     1.257048      5341.502803    30.274887    22.932220
# std      54.279780     1.370444       429.158867     3.128010     2.487613
# min      12.370000     0.098475      4329.520508    17.400000    11.300000
# 25%      28.700000     0.271300      4999.018555    28.200000    21.300000
# 50%      45.716000     0.618000      5436.345215    30.500000    23.100000
# 75%      59.832400     1.767800      5728.316406    32.600000    24.600000
# max     212.335000     5.178230      5992.895996    38.900000    29.800000

# %%
#replaced null values with mean of that particular column
for i in df.columns:
    df[i]=df[i].fillna(df[i].mean())

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# # Visualization of dataset

# %%
df.station.nunique()
# Out:
# 25

# %%
col=['Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
       'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
       'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
       'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'Next_Tmax', 'Next_Tmin']

for i in col:
    plt.figure(figsize=(12,5))
    sns.distplot(df[i])
    plt.title(i,fontsize=15)
    plt.show()

# %% [markdown]
# Observations:
#
# Present_Tmax, Present_Tmin and LDAPS_RHmin have nearly uniform distribution,LDAPS_RHmax is right skewed,LDAPS_Tmax_lapse and LDAPS_Tmin_lapse have uniform distribution,LDAPS_WS is left skewed,LDAPS_LH is slightly left skewed,LDAPS_CC1, LDAPS_CC2, LDAPS_CC3 and LDAPS_CC4 are left skewed,LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3 and LDAPS_PPT4 have most of the values near to 0,Next_Tmax and Next_Tmin have uniform distribution.

# %%
sns.scatterplot(df['Present_Tmax'],df['Next_Tmax'])
plt.show()
sns.scatterplot(df['Present_Tmin'],df['Next_Tmin'])
plt.show()

# %% [markdown]
# Present_Tmax and Next_Tmax have positive linear relaiton,Present_Tmin and Next_Tmin have positive linear relaiton

# %%
col=['LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_WS','LDAPS_LH','Solar radiation']
for i in col:
    sns.scatterplot(df[i],df['Next_Tmax'])
    plt.show()

# %% [markdown]
# LDAPS_Tmax_lapse have positive linear relation with Next_Tmin.

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7752.000000   7752.000000   7752.000000  7752.000000  7752.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.210637      2.956557      2.403036    14.596973     7.157124
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    46.046162    84.316923
# 50%      13.000000     29.900000     23.400000    55.313244    89.699505
# 75%      19.000000     32.000000     24.900000    67.038254    93.704500
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7752.000000       7752.000000  7752.000000  7752.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.932898          2.333973     2.173245    33.567001
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.693091         22.114651     5.686487    37.532764
# 50%           29.662273         23.735942     6.563068    57.310630
# 75%           31.683819         25.134000     8.007471    83.904586
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1    LDAPS_CC2    LDAPS_CC3    LDAPS_CC4   LDAPS_PPT1  \
# count  7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean      0.368774     0.356080     0.318404     0.299191     0.591995
# std       0.261185     0.256810     0.249148     0.253114     1.936331
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.148321     0.142328     0.103100     0.082741     0.000000
# 50%       0.320110     0.315667     0.265264     0.232354     0.000000
# 75%       0.571696     0.554963     0.494007     0.497230     0.067593
# max       0.967277     0.968353     0.983789     0.974710    23.701544
#
#         LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat          lon  \
# count  7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean      0.485003     0.278200     0.269407    37.544722   126.991397
# std       1.754258     1.156174     1.200364     0.050352     0.079435
# min       0.000000     0.000000     0.000000    37.456200   126.826000
# 25%       0.000000     0.000000     0.000000    37.510200   126.937000
# 50%       0.000000     0.000000     0.000000    37.550700   126.995000
# 75%       0.024276     0.009697     0.000693    37.577600   127.042000
# max      21.621661    15.841235    16.655469    37.645000   127.135000
#
#                DEM        Slope  Solar radiation    Next_Tmax    Next_Tmin
# count  7752.000000  7752.000000      7752.000000  7752.000000  7752.000000
# mean     61.867972     1.257048      5341.502803    30.274887    22.932220
# std      54.279780     1.370444       429.158867     3.122557     2.483276
# min      12.370000     0.098475      4329.520508    17.400000    11.300000
# 25%      28.700000     0.271300      4999.018555    28.200000    21.400000
# 50%      45.716000     0.618000      5436.345215    30.500000    23.100000
# 75%      59.832400     1.767800      5728.316406    32.600000    24.600000
# max     212.335000     5.178230      5992.895996    38.900000    29.800000

# %% [markdown]
# Observations:
#
# Average Present Tmax is 29.7 °C.
#
# Average Present Tmin is 23.2 °C.
#
# Average LDAPS Tmax lapse is 29.6 °C.
#
# Average LDAPS Tmin lapse is 23.5 °C.
#
# Majority of LDAPS PPTS value is 0%.
#
# The standard deviation is low in most of the columns which means data is not much deviated.
#
# There is no much difference in mean and median of the respective columns.

# %%
#Checking correlation
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
corr=df.corr()
corr['Next_Tmax'].sort_values(ascending=False)
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.827189
# Next_Tmin           0.621427
# Present_Tmax        0.610348
# LDAPS_Tmin_lapse    0.586983
# Present_Tmin        0.471806
# LDAPS_LH            0.157616
# station             0.107983
# Solar radiation     0.008795
# lon                 0.003052
# lat                -0.053510
# Slope              -0.102725
# LDAPS_PPT1         -0.118817
# DEM                -0.172538
# LDAPS_PPT2         -0.178383
# LDAPS_PPT4         -0.178718
# LDAPS_PPT3         -0.194143
# LDAPS_RHmax        -0.283738
# LDAPS_WS           -0.342729
# LDAPS_RHmin        -0.437898
# LDAPS_CC4          -0.446319
# LDAPS_CC1          -0.452541
# LDAPS_CC2          -0.490756
# LDAPS_CC3          -0.514680
# Name: Next_Tmax, dtype: float64

# %%
corr['Next_Tmin'].sort_values(ascending=False)
# Out:
# Next_Tmin           1.000000
# LDAPS_Tmin_lapse    0.880176
# Present_Tmin        0.796670
# Present_Tmax        0.622741
# Next_Tmax           0.621427
# LDAPS_Tmax_lapse    0.586868
# station             0.128293
# Solar radiation     0.120212
# LDAPS_RHmin         0.095019
# LDAPS_CC2           0.031250
# LDAPS_PPT1          0.021323
# LDAPS_PPT2         -0.008058
# LDAPS_CC1          -0.011028
# lon                -0.046603
# LDAPS_CC3          -0.054726
# LDAPS_LH           -0.055440
# LDAPS_PPT3         -0.062622
# LDAPS_RHmax        -0.071997
# lat                -0.083533
# LDAPS_CC4          -0.085093
# LDAPS_WS           -0.096576
# LDAPS_PPT4         -0.103682
# Slope              -0.146882
# DEM                -0.246906
# Name: Next_Tmin, dtype: float64

# %%
#Checking outliers
df.plot(kind='box',subplots=True,layout=(2,12),figsize=(20,10),color='green')
plt.tight_layout()

# %%
#Removing date column as we need to predcit the next day temperature based on the present day data therefore date in not needed.
df.drop(['Date'],axis=1,inplace=True)

# %%
#Check outlers using zscore
from scipy.stats import zscore
zscr=np.abs(zscore(df))
threshold=3
print(np.where(zscr>3))
# Out:
# (array([  25,   25,   26, ..., 7751, 7751, 7751], dtype=int64), array([ 7, 14, 14, ..., 14, 15, 16], dtype=int64))

# %%
print('shape before removing the outliers:' , df.shape)
df_new=df[(zscr<3).all(axis=1)]
print('shape after removing outliers :', df_new.shape)
# Out:
# shape before removing the outliers: (7752, 24)
# shape after removing outliers : (6894, 24)

# %%
print('Data loss =', 100-(6888/7750)*100)
# Out:
# Data loss = 11.122580645161293

# %%
#Seperating independetn and target variables
x=df.iloc[:,0:-2]
y_Tmax=df.iloc[:,-2]
y_Tmin=df.iloc[:,-1]

# %%
x.shape,y_Tmax.shape,y_Tmin.shape
# Out:
# ((7752, 22), (7752,), (7752,))

# %%
#Applying min-max scler to bring the variables to a standard scale
from sklearn.preprocessing import MinMaxScaler
col_name=x.columns.values
sc=MinMaxScaler(feature_range = (0,1))
sc.fit(x)
x=pd.DataFrame(sc.transform(x))
x.columns=col_name

# %%
x.head()
# Out:
#     station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0  0.000000      0.494318      0.543011     0.488518     0.783659
# 1  0.041667      0.676136      0.553763     0.412406     0.771200
# 2  0.083333      0.659091      0.645161     0.367024     0.609716
# 3  0.125000      0.681818      0.650538     0.488316     0.914366
# 4  0.166667      0.647727      0.569892     0.462078     0.760251
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  \
# 0          0.499546          0.569132  0.207447  0.365853   0.241862
# 1          0.584480          0.636121  0.148053  0.288703   0.233137
# 2          0.595982          0.670697  0.171575  0.150545   0.216426
# 3          0.577497          0.589934  0.145848  0.349446   0.223692
# 4          0.549257          0.600379  0.150325  0.535505   0.156529
#
#    LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0   0.210559   0.164361   0.134325         0.0         0.0         0.0
# 1   0.260000   0.162071   0.131041         0.0         0.0         0.0
# 2   0.265884   0.207455   0.145813         0.0         0.0         0.0
# 3   0.233388   0.163813   0.137732         0.0         0.0         0.0
# 4   0.258165   0.181840   0.174432         0.0         0.0         0.0
#
#    LDAPS_PPT4       lat       lon       DEM     Slope  Solar radiation
# 0         0.0  0.786017  0.533981  1.000000  0.528869         1.000000
# 1         0.0  0.786017  0.666667  0.161990  0.081820         0.925703
# 2         0.0  0.643008  0.750809  0.104702  0.032999         0.922242
# 3         0.0  1.000000  0.634304  0.166759  0.479615         0.918280
# 4         0.0  0.500530  1.000000  0.113360  0.080127         0.919835

# %%
#Find the best random state:
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
lr=LinearRegression()
ls=Lasso()
rd=Ridge()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y_Tmax,test_size=.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print('At random state',i,'Training accuracy is:', r2_score(y_train,pred_train))
    print('At random state',i,'Testing accuracy is:',r2_score(y_test,pred_test))
    print('\n')
# Out:
# At random state 0 Training accuracy is: 0.7652212494452753
# At random state 0 Testing accuracy is: 0.7793978297845288
#
#
# At random state 1 Training accuracy is: 0.7658239547754291
# At random state 1 Testing accuracy is: 0.7771807044191446
#
#
# At random state 2 Training accuracy is: 0.7690018162977624
# At random state 2 Testing accuracy is: 0.7642972412671033
#
#
# At random state 3 Training accuracy is: 0.7691301891647155
# At random state 3 Testing accuracy is: 0.7641247110575085
#
#
# At random state 4 Training accuracy is: 0.7647064061201253
# At random state 4 Testing accuracy is: 0.7814654998513355
#
#
# At random state 5 Training accuracy is: 0.7664338794125244
# At random state 5 Testing accuracy is: 0.7744597666687005
#
#
# At random state 6 Training accuracy is: 0.7678738904558544
# At random state 6 Testing accuracy is: 0.768776454321355
#
#
# At random state 7 Training accuracy is: 0.7692546903969374
# At random state 7 Testing accuracy is: 0.7628448358559287
#
#
# At random state 8 Training accuracy is: 0.7742569380276366
# At random state 8 Testing accuracy is: 0.7424022874117296
#
#
# At random state 9 Training accuracy is: 0.7671405754207605
# At random state 9 Testing accuracy is: 0.7720300298529299
#
#
# At random state 10 Training accuracy is: 0.7693292306372946
# At random state 10 Testing accuracy is: 0.7631841672119823
#
#
# At random state 11 Training accuracy is: 0.7680660383883529
# At random state 11 Testing accuracy is: 0.7684887941172834
#
#
# At random state 12 Training accuracy is: 0.7645578628929215
# At random state 12 Testing accuracy is: 0.7810170566399943
#
#
# At random state 13 Training accuracy is: 0.7682791104359924
# At random state 13 Testing accuracy is: 0.7674366481999345
#
#
# At random state 14 Training accuracy is: 0.7677579042181745
# At random state 14 Testing accuracy is: 0.7695733716808215
#
#
# At random state 15 Training accuracy is: 0.7731140858607123
# At random state 15 Testing accuracy is: 0.7476444015242327
#
#
# At random state 16 Training accuracy is: 0.767489858202633
# At random state 16 Testing accuracy is: 0.7706531095990904
#
#
# At random state 17 Training accuracy is: 0.7691052164719828
# At random state 17 Testing accuracy is: 0.7640807048109552
#
#
# At random state 18 Training accuracy is: 0.7746750273665862
# At random state 18 Testing accuracy is: 0.739541623411732
#
#
# At random state 19 Training accuracy is: 0.7716642650893357
# At random state 19 Testing accuracy is: 0.75293076780679
#
#
# At random state 20 Training accuracy is: 0.7659627685867048
# At random state 20 Testing accuracy is: 0.7758307409109274
#
#
# At random state 21 Training accuracy is: 0.7699105981885077
# At random state 21 Testing accuracy is: 0.7604695897354778
#
#
# At random state 22 Training accuracy is: 0.7732495495816382
# At random state 22 Testing accuracy is: 0.7472934426808296
#
#
# At random state 23 Training accuracy is: 0.7695508575440304
# At random state 23 Testing accuracy is: 0.7627639983422498
#
#
# At random state 24 Training accuracy is: 0.7636895640868464
# At random state 24 Testing accuracy is: 0.785037754426357
#
#
# At random state 25 Training accuracy is: 0.7685730888005147
# At random state 25 Testing accuracy is: 0.7661527288256842
#
#
# At random state 26 Training accuracy is: 0.7688984584504313
# At random state 26 Testing accuracy is: 0.7652099278155777
#
#
# At random state 27 Training accuracy is: 0.7679023754417638
# At random state 27 Testing accuracy is: 0.7684293708413454
#
#
# At random state 28 Training accuracy is: 0.7646884625153157
# At random state 28 Testing accuracy is: 0.7805240690412304
#
#
# At random state 29 Training accuracy is: 0.7716235927615541
# At random state 29 Testing accuracy is: 0.7535318391513566
#
#
# At random state 30 Training accuracy is: 0.7675920383246815
# At random state 30 Testing accuracy is: 0.7700341993216963
#
#
# At random state 31 Training accuracy is: 0.7701580204627376
# At random state 31 Testing accuracy is: 0.7593763480493463
#
#
# At random state 32 Training accuracy is: 0.7696238623124078
# At random state 32 Testing accuracy is: 0.7615080580279868
#
#
# At random state 33 Training accuracy is: 0.77097734047274
# At random state 33 Testing accuracy is: 0.7561341637216591
#
#
# At random state 34 Training accuracy is: 0.7675238912770629
# At random state 34 Testing accuracy is: 0.7696803796161381
#
#
# At random state 35 Training accuracy is: 0.7715397879458767
# At random state 35 Testing accuracy is: 0.7537837749091736
#
#
# At random state 36 Training accuracy is: 0.7665409965527483
# At random state 36 Testing accuracy is: 0.774363363807895
#
#
# At random state 37 Training accuracy is: 0.7706032397652278
# At random state 37 Testing accuracy is: 0.7579638585493472
#
#
# At random state 38 Training accuracy is: 0.7648434796710314
# At random state 38 Testing accuracy is: 0.7813333549019796
#
#
# At random state 39 Training accuracy is: 0.7679608629819965
# At random state 39 Testing accuracy is: 0.7687116499722354
#
#
# At random state 40 Training accuracy is: 0.7680201164413124
# At random state 40 Testing accuracy is: 0.7678815062980389
#
#
# At random state 41 Training accuracy is: 0.769226001519612
# At random state 41 Testing accuracy is: 0.7639655227794219
#
#
# At random state 42 Training accuracy is: 0.767856233175673
# At random state 42 Testing accuracy is: 0.7687430345436446
#
#
# At random state 43 Training accuracy is: 0.7644782923523799
# At random state 43 Testing accuracy is: 0.7827703052910088
#
#
# At random state 44 Training accuracy is: 0.7691202318805199
# At random state 44 Testing accuracy is: 0.7635794292667077
#
#
# At random state 45 Training accuracy is: 0.7674631762607288
# At random state 45 Testing accuracy is: 0.7699642588892209
#
#
# At random state 46 Training accuracy is: 0.7667076632717851
# At random state 46 Testing accuracy is: 0.7736757761219732
#
#
# At random state 47 Training accuracy is: 0.7724870083142492
# At random state 47 Testing accuracy is: 0.7489544615630452
#
#
# At random state 48 Training accuracy is: 0.7682908210395492
# At random state 48 Testing accuracy is: 0.7673653510654873
#
#
# At random state 49 Training accuracy is: 0.7676672902189565
# At random state 49 Testing accuracy is: 0.7701887836225079
#
#
# At random state 50 Training accuracy is: 0.7772137729741619
# At random state 50 Testing accuracy is: 0.730115621699265
#
#
# At random state 51 Training accuracy is: 0.7666330304456813
# At random state 51 Testing accuracy is: 0.7738583483908009
#
#
# At random state 52 Training accuracy is: 0.7676011163108687
# At random state 52 Testing accuracy is: 0.7699735302259798
#
#
# At random state 53 Training accuracy is: 0.7681936730227623
# At random state 53 Testing accuracy is: 0.7674341765091002
#
#
# At random state 54 Training accuracy is: 0.7690157934616999
# At random state 54 Testing accuracy is: 0.7642754602236341
#
#
# At random state 55 Training accuracy is: 0.7698987669900368
# At random state 55 Testing accuracy is: 0.7607995006869244
#
#
# At random state 56 Training accuracy is: 0.7642545118926478
# At random state 56 Testing accuracy is: 0.7819159001290693
#
#
# At random state 57 Training accuracy is: 0.7722929603993333
# At random state 57 Testing accuracy is: 0.7517177022726331
#
#
# At random state 58 Training accuracy is: 0.7686313733010994
# At random state 58 Testing accuracy is: 0.7650831514968164
#
#
# At random state 59 Training accuracy is: 0.7627840900578848
# At random state 59 Testing accuracy is: 0.7880372251398471
#
#
# At random state 60 Training accuracy is: 0.7679898781183753
# At random state 60 Testing accuracy is: 0.7682760036974831
#
#
# At random state 61 Training accuracy is: 0.7640771325582993
# At random state 61 Testing accuracy is: 0.7846418345153576
#
#
# At random state 62 Training accuracy is: 0.7660831481657477
# At random state 62 Testing accuracy is: 0.7761324146922198
#
#
# At random state 63 Training accuracy is: 0.7666009262618049
# At random state 63 Testing accuracy is: 0.7731631502604537
#
#
# At random state 64 Training accuracy is: 0.7707939189883248
# At random state 64 Testing accuracy is: 0.7569126889733032
#
#
# At random state 65 Training accuracy is: 0.7708971242843679
# At random state 65 Testing accuracy is: 0.7572684739789304
#
#
# At random state 66 Training accuracy is: 0.7717433661079279
# At random state 66 Testing accuracy is: 0.7537335825841538
#
#
# At random state 67 Training accuracy is: 0.76676451818267
# At random state 67 Testing accuracy is: 0.7737987598803336
#
#
# At random state 68 Training accuracy is: 0.7662368818269573
# At random state 68 Testing accuracy is: 0.7749510430684144
#
#
# At random state 69 Training accuracy is: 0.7675041087470588
# At random state 69 Testing accuracy is: 0.7707788215861002
#
#
# At random state 70 Training accuracy is: 0.769929600966884
# At random state 70 Testing accuracy is: 0.7607299726088137
#
#
# At random state 71 Training accuracy is: 0.7660785740098163
# At random state 71 Testing accuracy is: 0.7753163669497871
#
#
# At random state 72 Training accuracy is: 0.7678137623110318
# At random state 72 Testing accuracy is: 0.7690629081776694
#
#
# At random state 73 Training accuracy is: 0.7664252843403113
# At random state 73 Testing accuracy is: 0.7744126377780919
#
#
# At random state 74 Training accuracy is: 0.7681816924495226
# At random state 74 Testing accuracy is: 0.7678008801716282
#
#
# At random state 75 Training accuracy is: 0.7723798118982386
# At random state 75 Testing accuracy is: 0.7516283331749398
#
#
# At random state 76 Training accuracy is: 0.768987546223628
# At random state 76 Testing accuracy is: 0.7650512919853438
#
#
# At random state 77 Training accuracy is: 0.7698258864607759
# At random state 77 Testing accuracy is: 0.760741370685665
#
#
# At random state 78 Training accuracy is: 0.7662445100617283
# At random state 78 Testing accuracy is: 0.7757453488979699
#
#
# At random state 79 Training accuracy is: 0.7642527154122305
# At random state 79 Testing accuracy is: 0.7840521558607383
#
#
# At random state 80 Training accuracy is: 0.769190233876837
# At random state 80 Testing accuracy is: 0.7639572141586727
#
#
# At random state 81 Training accuracy is: 0.7693622011954703
# At random state 81 Testing accuracy is: 0.7628759161871245
#
#
# At random state 82 Training accuracy is: 0.7680423739487358
# At random state 82 Testing accuracy is: 0.768556972023139
#
#
# At random state 83 Training accuracy is: 0.7730186860718324
# At random state 83 Testing accuracy is: 0.7486339250309171
#
#
# At random state 84 Training accuracy is: 0.7677199982953827
# At random state 84 Testing accuracy is: 0.7694434248154726
#
#
# At random state 85 Training accuracy is: 0.7735223879920131
# At random state 85 Testing accuracy is: 0.7463892398604829
#
#
# At random state 86 Training accuracy is: 0.7660989546664034
# At random state 86 Testing accuracy is: 0.7761710049205437
#
#
# At random state 87 Training accuracy is: 0.7707287123258612
# At random state 87 Testing accuracy is: 0.757659888484885
#
#
# At random state 88 Training accuracy is: 0.7646876151944357
# At random state 88 Testing accuracy is: 0.7808250816246243
#
#
# At random state 89 Training accuracy is: 0.7660467219892619
# At random state 89 Testing accuracy is: 0.7762583989177816
#
#
# At random state 90 Training accuracy is: 0.7635543014579609
# At random state 90 Testing accuracy is: 0.7856883828267448
#
#
# At random state 91 Training accuracy is: 0.7716873711000365
# At random state 91 Testing accuracy is: 0.7523227200168752
#
#
# At random state 92 Training accuracy is: 0.7695568721106353
# At random state 92 Testing accuracy is: 0.7622450584046998
#
#
# At random state 93 Training accuracy is: 0.7690387306714878
# At random state 93 Testing accuracy is: 0.7643544436485813
#
#
# At random state 94 Training accuracy is: 0.7653860853052026
# At random state 94 Testing accuracy is: 0.778318267052406
#
#
# At random state 95 Training accuracy is: 0.7700070346133507
# At random state 95 Testing accuracy is: 0.7602373893790113
#
#
# At random state 96 Training accuracy is: 0.7695858769637163
# At random state 96 Testing accuracy is: 0.7619304413155158
#
#
# At random state 97 Training accuracy is: 0.7706145456323099
# At random state 97 Testing accuracy is: 0.7575024882779468
#
#
# At random state 98 Training accuracy is: 0.7717980564695746
# At random state 98 Testing accuracy is: 0.7537643527579163
#
#
# At random state 99 Training accuracy is: 0.7683458914431786
# At random state 99 Testing accuracy is: 0.7665338011595386

# %%
#Doing train test split at random state 81
x_train,x_test,y_train,y_test=train_test_split(x,y_Tmax,test_size=.20,random_state=81)

x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((6201, 22), (1551, 22), (6201,), (1551,))

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import cross_val_score
svr=SVR()
knn=KNeighborsRegressor()
rf=RandomForestRegressor()
ada=AdaBoostRegressor()

# %%
model=[lr,ls,rd,svr,knn,rf,ada]

for i in model:
    print('\n')
    print(i)
    i.fit(x_train,y_train)
    pred=i.predict(x_test)
    score=i.score(x_train,y_train)
    print('score:',score)
    print('mean absolute error:',mean_absolute_error(y_test,pred))
    print('Root mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
    print('r2_score:',r2_score(y_test,pred))
    scores=cross_val_score(i, x, y_Tmax, cv=5)
    print('Cross Validation Score:',scores.mean())
# Out:
# LinearRegression()
# score: 0.7693622011954703
# mean absolute error: 1.121187789087732
# Root mean squared error: 1.4864958757040416
# r2_score: 0.7628759161871245
# Cross Validation Score: 0.7031501370168671
#
#
# Lasso()
# score: 0.0
# mean absolute error: 2.4802004823969206
# Root mean squared error: 3.0543910295773236
# r2_score: -0.0011462382617508649
# Cross Validation Score: -0.040829379307384436
#
#
# Ridge()
# score: 0.7691964451684261
# mean absolute error: 1.1186759119935696
# Root mean squared error: 1.4845257556453768
# r2_score: 0.7635040421651349
# Cross Validation Score: 0.7037088450199978
#
#
# SVR()
# score: 0.8214261549391325
# mean absolute error: 0.9506943938677878
# Root mean squared error: 1.306605910865474
# r2_score: 0.8167949309858773
# Cross Validation Score: 0.6956650886759659
#
#
# KNeighborsRegressor()
# score: 0.8442247097576805
# mean absolute error: 1.1630079268203624
# Root mean squared error: 1.5412469222499054
# r2_score: 0.7450865836518625
# Cross Validation Score: 0.5364365403964252
#
#
# RandomForestRegressor()
# score: 0.9855425782949994
# mean absolute error: 0.7207968659952139
# Root mean squared error: 0.966523569601731
# r2_score: 0.8997525932065353
# Cross Validation Score: 0.6831518353254521
#
#
# AdaBoostRegressor()
# score: 0.7513038415099174
# mean absolute error: 1.292432192751792
# Root mean squared error: 1.5818975242599256
# r2_score: 0.7314625000075027
# Cross Validation Score: 0.6590724948122207

# %%
from sklearn.model_selection import GridSearchCV
parameters={'kernel': ['rbf', 'poly', 'sigmoid']}
clf=GridSearchCV(svr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'kernel': 'poly'}

# %%
svr=SVR(kernel='poly')
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
print('mean absolute error:',mean_absolute_error(y_test,pred_svr))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_svr)))
print('R2 score is:',r2_score(y_test,pred_svr))
cv_score=cross_val_score(svr,x,y_Tmax,cv=5)
cv_mean=cv_score.mean()
print('Cross Val Score is:',cv_mean)
# Out:
# mean absolute error: 0.9400314109640286
# Root mean squared error: 1.2910344826543494
# R2 score is: 0.8211355905491802
# Cross Val Score is: 0.6602284277501574

# %%
#ploting our model
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_svr, color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Next_Tmax')
plt.ylabel('Predicted Next_Tmax')
plt.title('SVR')
plt.show()

# %%
#Saving our model
import joblib
joblib.dump(svr,'Next_Tmax_prediction_svr.obj')
# Out:
# ['Next_Tmax_prediction_svr.obj']

# %% [markdown]
# # train models for Next_Tmin

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y_Tmin,test_size=.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print('At random state',i,'Training accuracy is:', r2_score(y_train,pred_train))
    print('At random state',i,'Testing accuracy is:',r2_score(y_test,pred_test))
    print('\n')
# Out:
# At random state 0 Training accuracy is: 0.8311249270034125
# At random state 0 Testing accuracy is: 0.8252148810689561
#
#
# At random state 1 Training accuracy is: 0.8281504384433764
# At random state 1 Testing accuracy is: 0.83783144691543
#
#
# At random state 2 Training accuracy is: 0.8306294810096488
# At random state 2 Testing accuracy is: 0.8272916607569766
#
#
# At random state 3 Training accuracy is: 0.8300361123619714
# At random state 3 Testing accuracy is: 0.8299861978356948
#
#
# At random state 4 Training accuracy is: 0.8279713843059449
# At random state 4 Testing accuracy is: 0.8381754847610574
#
#
# At random state 5 Training accuracy is: 0.8303507576250945
# At random state 5 Testing accuracy is: 0.8284136920819039
#
#
# At random state 6 Training accuracy is: 0.8286725966807315
# At random state 6 Testing accuracy is: 0.8351290884213943
#
#
# At random state 7 Training accuracy is: 0.8279998318021534
# At random state 7 Testing accuracy is: 0.838301756981587
#
#
# At random state 8 Training accuracy is: 0.8325264775648312
# At random state 8 Testing accuracy is: 0.8197681233483225
#
#
# At random state 9 Training accuracy is: 0.8284115044767492
# At random state 9 Testing accuracy is: 0.8364763265721251
#
#
# At random state 10 Training accuracy is: 0.826865296450134
# At random state 10 Testing accuracy is: 0.8420782589566028
#
#
# At random state 11 Training accuracy is: 0.8308189515966086
# At random state 11 Testing accuracy is: 0.826747938414418
#
#
# At random state 12 Training accuracy is: 0.8276667751986523
# At random state 12 Testing accuracy is: 0.8388584559803963
#
#
# At random state 13 Training accuracy is: 0.8335438344962712
# At random state 13 Testing accuracy is: 0.8151996077127334
#
#
# At random state 14 Training accuracy is: 0.8328940279753707
# At random state 14 Testing accuracy is: 0.8187282257002922
#
#
# At random state 15 Training accuracy is: 0.8337796949192423
# At random state 15 Testing accuracy is: 0.8153773839882836
#
#
# At random state 16 Training accuracy is: 0.8293313301716698
# At random state 16 Testing accuracy is: 0.8323766432795007
#
#
# At random state 17 Training accuracy is: 0.8299511715255604
# At random state 17 Testing accuracy is: 0.829542722915456
#
#
# At random state 18 Training accuracy is: 0.8302773771450075
# At random state 18 Testing accuracy is: 0.8288083898771228
#
#
# At random state 19 Training accuracy is: 0.830666560124286
# At random state 19 Testing accuracy is: 0.8278410848118406
#
#
# At random state 20 Training accuracy is: 0.8264998738250643
# At random state 20 Testing accuracy is: 0.8444555704888707
#
#
# At random state 21 Training accuracy is: 0.8288871576211239
# At random state 21 Testing accuracy is: 0.8345879555095996
#
#
# At random state 22 Training accuracy is: 0.8312665281229719
# At random state 22 Testing accuracy is: 0.824347518497982
#
#
# At random state 23 Training accuracy is: 0.8312291374936327
# At random state 23 Testing accuracy is: 0.8248374621080564
#
#
# At random state 24 Training accuracy is: 0.8304613350175718
# At random state 24 Testing accuracy is: 0.828499877119354
#
#
# At random state 25 Training accuracy is: 0.8323510747127731
# At random state 25 Testing accuracy is: 0.8211733522874441
#
#
# At random state 26 Training accuracy is: 0.8306738845668759
# At random state 26 Testing accuracy is: 0.8277086773361779
#
#
# At random state 27 Training accuracy is: 0.8332389033490705
# At random state 27 Testing accuracy is: 0.8164096853931155
#
#
# At random state 28 Training accuracy is: 0.8325043516334385
# At random state 28 Testing accuracy is: 0.8201637526102055
#
#
# At random state 29 Training accuracy is: 0.8281430695735166
# At random state 29 Testing accuracy is: 0.8376553074629447
#
#
# At random state 30 Training accuracy is: 0.8301961802750074
# At random state 30 Testing accuracy is: 0.829166413187141
#
#
# At random state 31 Training accuracy is: 0.8325417126716744
# At random state 31 Testing accuracy is: 0.8192873013067423
#
#
# At random state 32 Training accuracy is: 0.8333312457087645
# At random state 32 Testing accuracy is: 0.816613612757777
#
#
# At random state 33 Training accuracy is: 0.8313304701468376
# At random state 33 Testing accuracy is: 0.8247078271812666
#
#
# At random state 34 Training accuracy is: 0.8307684208468912
# At random state 34 Testing accuracy is: 0.8267503201016118
#
#
# At random state 35 Training accuracy is: 0.8297327560465543
# At random state 35 Testing accuracy is: 0.8310423943283973
#
#
# At random state 36 Training accuracy is: 0.8282599830606278
# At random state 36 Testing accuracy is: 0.8367604738939911
#
#
# At random state 37 Training accuracy is: 0.8304901486327196
# At random state 37 Testing accuracy is: 0.8285314966954431
#
#
# At random state 38 Training accuracy is: 0.8320202018009553
# At random state 38 Testing accuracy is: 0.8218326497945292
#
#
# At random state 39 Training accuracy is: 0.8301259562793406
# At random state 39 Testing accuracy is: 0.8297941321306112
#
#
# At random state 40 Training accuracy is: 0.8292955427169323
# At random state 40 Testing accuracy is: 0.8330328415413506
#
#
# At random state 41 Training accuracy is: 0.8306785313734
# At random state 41 Testing accuracy is: 0.8277384850458018
#
#
# At random state 42 Training accuracy is: 0.8260868435109111
# At random state 42 Testing accuracy is: 0.8452287751533523
#
#
# At random state 43 Training accuracy is: 0.8273075141497376
# At random state 43 Testing accuracy is: 0.8407305032543726
#
#
# At random state 44 Training accuracy is: 0.8299025871746694
# At random state 44 Testing accuracy is: 0.8295303346221016
#
#
# At random state 45 Training accuracy is: 0.8305794263092918
# At random state 45 Testing accuracy is: 0.8276781205491899
#
#
# At random state 46 Training accuracy is: 0.8316686754176679
# At random state 46 Testing accuracy is: 0.8239610720169301
#
#
# At random state 47 Training accuracy is: 0.8301862521873904
# At random state 47 Testing accuracy is: 0.8297342618477614
#
#
# At random state 48 Training accuracy is: 0.8316487438024013
# At random state 48 Testing accuracy is: 0.8236092792276712
#
#
# At random state 49 Training accuracy is: 0.8319613509525288
# At random state 49 Testing accuracy is: 0.8215153207294474
#
#
# At random state 50 Training accuracy is: 0.8355738593343569
# At random state 50 Testing accuracy is: 0.8060639320534888
#
#
# At random state 51 Training accuracy is: 0.829402045959956
# At random state 51 Testing accuracy is: 0.8324173725730515
#
#
# At random state 52 Training accuracy is: 0.8289836279184978
# At random state 52 Testing accuracy is: 0.8340116116867373
#
#
# At random state 53 Training accuracy is: 0.8300189916380942
# At random state 53 Testing accuracy is: 0.829871103015903
#
#
# At random state 54 Training accuracy is: 0.8278827332037622
# At random state 54 Testing accuracy is: 0.8381370509426096
#
#
# At random state 55 Training accuracy is: 0.8275964122924779
# At random state 55 Testing accuracy is: 0.8399638217886897
#
#
# At random state 56 Training accuracy is: 0.8271561673398252
# At random state 56 Testing accuracy is: 0.8402495630071203
#
#
# At random state 57 Training accuracy is: 0.831880856231656
# At random state 57 Testing accuracy is: 0.8225439199123726
#
#
# At random state 58 Training accuracy is: 0.8299488325495793
# At random state 58 Testing accuracy is: 0.8295062472763031
#
#
# At random state 59 Training accuracy is: 0.8297898736359922
# At random state 59 Testing accuracy is: 0.8309083064350956
#
#
# At random state 60 Training accuracy is: 0.8274170880812959
# At random state 60 Testing accuracy is: 0.8404198446960984
#
#
# At random state 61 Training accuracy is: 0.8310828044061368
# At random state 61 Testing accuracy is: 0.8259124114225525
#
#
# At random state 62 Training accuracy is: 0.8298448955920896
# At random state 62 Testing accuracy is: 0.8307068322206876
#
#
# At random state 63 Training accuracy is: 0.8322469379823765
# At random state 63 Testing accuracy is: 0.819974753473474
#
#
# At random state 64 Training accuracy is: 0.8326460099420183
# At random state 64 Testing accuracy is: 0.8185421853554447
#
#
# At random state 65 Training accuracy is: 0.8296766853987942
# At random state 65 Testing accuracy is: 0.8313737715371528
#
#
# At random state 66 Training accuracy is: 0.8297089645856135
# At random state 66 Testing accuracy is: 0.8311287427268415
#
#
# At random state 67 Training accuracy is: 0.8325181484002361
# At random state 67 Testing accuracy is: 0.819570367218367
#
#
# At random state 68 Training accuracy is: 0.8298062910362212
# At random state 68 Testing accuracy is: 0.8310694711787228
#
#
# At random state 69 Training accuracy is: 0.8270201361513438
# At random state 69 Testing accuracy is: 0.8417604585711079
#
#
# At random state 70 Training accuracy is: 0.8308573906197544
# At random state 70 Testing accuracy is: 0.8263221824140772
#
#
# At random state 71 Training accuracy is: 0.8294467992659563
# At random state 71 Testing accuracy is: 0.8325656937587685
#
#
# At random state 72 Training accuracy is: 0.8314266026827691
# At random state 72 Testing accuracy is: 0.8248070422341376
#
#
# At random state 73 Training accuracy is: 0.8320216228962357
# At random state 73 Testing accuracy is: 0.8220704781198627
#
#
# At random state 74 Training accuracy is: 0.8291551743361096
# At random state 74 Testing accuracy is: 0.8335599002207998
#
#
# At random state 75 Training accuracy is: 0.8290376917591709
# At random state 75 Testing accuracy is: 0.833503411190569
#
#
# At random state 76 Training accuracy is: 0.830364409475217
# At random state 76 Testing accuracy is: 0.8287497572061862
#
#
# At random state 77 Training accuracy is: 0.8324072441108679
# At random state 77 Testing accuracy is: 0.8209294358250283
#
#
# At random state 78 Training accuracy is: 0.8297876752668853
# At random state 78 Testing accuracy is: 0.8309000468891891
#
#
# At random state 79 Training accuracy is: 0.8319565201293693
# At random state 79 Testing accuracy is: 0.8223621992452017
#
#
# At random state 80 Training accuracy is: 0.8321760858710128
# At random state 80 Testing accuracy is: 0.821423270558803
#
#
# At random state 81 Training accuracy is: 0.8289226850733153
# At random state 81 Testing accuracy is: 0.8350515415387925
#
#
# At random state 82 Training accuracy is: 0.8285659578882035
# At random state 82 Testing accuracy is: 0.8359253072924426
#
#
# At random state 83 Training accuracy is: 0.829713196056859
# At random state 83 Testing accuracy is: 0.8311674717280778
#
#
# At random state 84 Training accuracy is: 0.8304804294651698
# At random state 84 Testing accuracy is: 0.8277455520496599
#
#
# At random state 85 Training accuracy is: 0.8294598554451634
# At random state 85 Testing accuracy is: 0.8323605145795387
#
#
# At random state 86 Training accuracy is: 0.829412680983129
# At random state 86 Testing accuracy is: 0.8326307564643229
#
#
# At random state 87 Training accuracy is: 0.8321340030519835
# At random state 87 Testing accuracy is: 0.8212179357368867
#
#
# At random state 88 Training accuracy is: 0.8282818255854356
# At random state 88 Testing accuracy is: 0.8370878698848512
#
#
# At random state 89 Training accuracy is: 0.8284936198683344
# At random state 89 Testing accuracy is: 0.836333440546262
#
#
# At random state 90 Training accuracy is: 0.8288180085635009
# At random state 90 Testing accuracy is: 0.834790203940939
#
#
# At random state 91 Training accuracy is: 0.8311887288613257
# At random state 91 Testing accuracy is: 0.8251676315876533
#
#
# At random state 92 Training accuracy is: 0.8317344938890988
# At random state 92 Testing accuracy is: 0.8235538909719531
#
#
# At random state 93 Training accuracy is: 0.8282531692565944
# At random state 93 Testing accuracy is: 0.8362527120341785
#
#
# At random state 94 Training accuracy is: 0.830663696022441
# At random state 94 Testing accuracy is: 0.8277203659188201
#
#
# At random state 95 Training accuracy is: 0.8296341640190787
# At random state 95 Testing accuracy is: 0.8315640931968491
#
#
# At random state 96 Training accuracy is: 0.8307538833333672
# At random state 96 Testing accuracy is: 0.8268067658224338
#
#
# At random state 97 Training accuracy is: 0.8290240231101771
# At random state 97 Testing accuracy is: 0.8337284009167405
#
#
# At random state 98 Training accuracy is: 0.8282681896050011
# At random state 98 Testing accuracy is: 0.8364076035146685
#
#
# At random state 99 Training accuracy is: 0.8282201442761163
# At random state 99 Testing accuracy is: 0.8369179019197499

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y_Tmin,test_size=.20,random_state=67)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((6201, 22), (1551, 22), (6201,), (1551,))

# %%
svr=SVR()
knn=KNeighborsRegressor()
rf=RandomForestRegressor()
ada=AdaBoostRegressor()

model=[lr,ls,rd,svr,knn,rf,ada]
for i in model:
    print('\n')
    print(i)
    i.fit(x_train,y_train)
    pred=i.predict(x_test)
    score=i.score(x_train,y_train)
    print('score:',score)
    print('mean absolute error:',mean_absolute_error(y_test,pred))
    print('Root mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
    print('r2_score:',r2_score(y_test,pred))
    scores=cross_val_score(i, x, y_Tmin, cv=5)
    print('Cross Validation Score:',scores.mean())
# Out:
# LinearRegression()
# score: 0.8325181484002361
# mean absolute error: 0.806906131358755
# Root mean squared error: 1.0323782637637804
# r2_score: 0.819570367218367
# Cross Validation Score: 0.7763074508027094
#
#
# Lasso()
# score: 0.0
# mean absolute error: 1.9139724467950898
# Root mean squared error: 2.430574855715393
# r2_score: -0.00011090475808495093
# Cross Validation Score: -0.16261899101319593
#
#
# Ridge()
# score: 0.8324650120249333
# mean absolute error: 0.8073900318246243
# Root mean squared error: 1.0325444902951961
# r2_score: 0.819512259434342
# Cross Validation Score: 0.7768038418048471
#
#
# SVR()
# score: 0.8812304191926793
# mean absolute error: 0.6764306246752593
# Root mean squared error: 0.9064478764692577
# r2_score: 0.8609036183281276
# Cross Validation Score: 0.7788974081351909
#
#
# KNeighborsRegressor()
# score: 0.8702404953885114
# mean absolute error: 0.8511116853308963
# Root mean squared error: 1.119592372185504
# r2_score: 0.7877977312106609
# Cross Validation Score: 0.5820588303978884
#
#
# RandomForestRegressor()
# score: 0.9867853371578751
# mean absolute error: 0.5777379356882185
# Root mean squared error: 0.7823792275916187
# r2_score: 0.8963749427287617
# Cross Validation Score: 0.7735532224680922
#
#
# AdaBoostRegressor()
# score: 0.8097864275284171
# mean absolute error: 0.8780086005346526
# Root mean squared error: 1.1007144430385856
# r2_score: 0.794893468121775
# Cross Validation Score: 0.7318769490991001

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters={'kernel': ['rbf', 'poly', 'sigmoid']}
clf=GridSearchCV(svr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'kernel': 'rbf'}

# %%
svr=SVR(kernel='rbf')
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
print('mean absolute error:',mean_absolute_error(y_test,pred_svr))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_svr)))
print('R2 score is:',r2_score(y_test,pred_svr))
cv_score=cross_val_score(svr,x,y_Tmin,cv=5)
cv_mean=cv_score.mean()
print('Cross Val Score is:',cv_mean)
# Out:
# mean absolute error: 0.6764306246752593
# Root mean squared error: 0.9064478764692577
# R2 score is: 0.8609036183281276
# Cross Val Score is: 0.7788974081351909

# %% [markdown]
# Our final results remains the same with MAE- 0.67, RMSE- 0.90, r2 score of 86% and cross val score of 78%.

# %%
#ploting our model
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_svr, color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Next_Tmin')
plt.ylabel('Predicted Next_Tmin')
plt.title('SVR')
plt.show()

# %%
#Saving our model
import joblib
joblib.dump(svr,'Next_Tmin_prediction_svr.obj')
# Out:
# ['Next_Tmin_prediction_svr.obj']
