# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# key observation:
#  1. the mean is more than the median(50th percentile)in all column
#  2. there is a large difference in 75% percentile and max in residual sugar,free sulphur dioxide, total sulphurdioxide
#  3. the 1 and 2 observation suggest that there are extreme outlier present inthese three column

# %% [markdown]
# # Exploring data variable

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [markdown]
# target/dependent variable is discreate and categorical in nature
#
# quality score scale ranges from 1 to 10;
# where 1 is low quality and 10 is best
#
#
# Only scores obtained are between 3 to 8

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# observation-
# quality has most values concentrated in the categories of 5,6,7
# few observation are present inthe categoriesin 3 and 8

# %% [markdown]
# # Data visualization

# %% [markdown]
# to check missing values

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# # To Check Correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(dfcor)

# %%
sns.color_palette
# Out:
# <function seaborn.palettes.color_palette(palette=None, n_colors=None, desat=None)>

# %%
sns.heatmap
# Out:
# <function seaborn.matrix.heatmap(data, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)>

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,cmap='Blues',annot=True)

# %% [markdown]
# dark shades are highly correletad

# %% [markdown]
# cmap : matplotlab colormap name
# colormap gives
# #https://matplotlib.org/3.1.0/gallary/color/colormap_refrence.html

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)

# %% [markdown]
# light shades are highly correlatad
#
# quality is highly correlatad with alcohal
#
# alcohal is highly negatively correlated with desnity with -0.5 (see i dark maroon shade)
# density is  highly positvie with residual sugar
# volatile acidity is negativily with quality
# fre sulphuric acid is negatively correleatd with quality

# %% [markdown]
# # ploting outlier

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#univariate analysis
df['fixed acidity'].plot.box()

# %%
df['citric acid'].plot.box()

# %%
df['free sulfur dioxide'].plot.box()

# %%
df['total sulfur dioxide'].plot.box()

# %%
df.shape
# Out:
# (1599, 12)

# %%
collist=df.columns.values
ncol=12
nrows=10

# %%
plt.subplot?

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len (collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# # to check distribution skewness

# %%
sns.distplot(df['density'])

# %%
sns.distplot(df['citric acid'])

# %%
#plt.figure(figsize=(5*totalcol,5*totalcol))
plt.figure(figsize=(16,16))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %% [markdown]
# only density and ph data is normal distribution
# other independent variable are right skewed/positively skewed

# %%
#bivariate analysis
plt.scatter(df['pH'],df['quality'])

# %% [markdown]
# sns.pairplot(df)

# %%
# remove the missing values
# drop negatively correletaed columns
#remove outliers

# %%
#data cleaning is done

# %%
plt.scatter(df['volatile acidity'],df['quality'])
plt.show()

# %%
df.drop('volatile acidity',axis=1,inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0            7.4         0.00             1.9      0.076                 11.0
# 1            7.8         0.00             2.6      0.098                 25.0
# 2            7.8         0.04             2.3      0.092                 15.0
# 3           11.2         0.56             1.9      0.075                 17.0
# 4            7.4         0.00             1.9      0.076                 11.0
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                  34.0   0.9978  3.51       0.56      9.4        5
# 1                  67.0   0.9968  3.20       0.68      9.8        5
# 2                  54.0   0.9970  3.26       0.65      9.8        5
# 3                  60.0   0.9980  3.16       0.58      9.8        6
# 4                  34.0   0.9978  3.51       0.56      9.4        5

# %%
df.shape
# Out:
# (1599, 11)

# %% [markdown]
# # Removing Outlier

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.52835961, 1.39147228, 0.45321841, ..., 0.57920652, 0.96024611,
#         0.78782264],
#        [0.29854743, 1.39147228, 0.04341614, ..., 0.1289504 , 0.58477711,
#         0.78782264],
#        [0.29854743, 1.18607043, 0.16942723, ..., 0.04808883, 0.58477711,
#         0.78782264],
#        ...,
#        [1.1603431 , 0.72391627, 0.16942723, ..., 0.54204194, 0.54162988,
#         0.45084835],
#        [1.39015528, 0.77526673, 0.38227061, ..., 0.30598963, 0.20930812,
#         0.78782264],
#        [1.33270223, 1.02199944, 0.75289408, ..., 0.01092425, 0.54162988,
#         0.45084835]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   42,   43,   45,
#          57,   81,   81,   83,   86,   88,   91,   92,   95,  106,  106,
#         109,  142,  144,  147,  151,  151,  151,  151,  163,  164,  169,
#         169,  181,  226,  226,  240,  243,  244,  258,  258,  274,  281,
#         291,  324,  325,  339,  340,  347,  354,  374,  381,  391,  396,
#         396,  400,  400,  442,  442,  451,  459,  467,  480,  480,  494,
#         515,  517,  544,  554,  554,  555,  555,  557,  557,  568,  584,
#         588,  591,  595,  608,  614,  636,  639,  649,  649,  651,  652,
#         652,  652,  672,  684,  690,  692,  692,  695,  723,  730,  754,
#         776,  777,  795,  821,  832,  836,  837,  889,  899,  911,  917,
#         923,  925,  926,  982, 1017, 1018, 1043, 1051, 1051, 1071, 1074,
#        1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186,
#        1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288,
# ...

# %%
#row and column

z[13][8]
# Out:
# 5.32210116796055

# %%
z[15][5]
# Out:
# 3.087489568732511

# %%
z[1589][2]
# Out:
# 3.732701384742145

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      0.076
# 1               7.8         0.00             2.6      0.098
# 2               7.8         0.04             2.3      0.092
# 3              11.2         0.56             1.9      0.075
# 4               7.4         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1594            6.2         0.08             2.0      0.090
# 1595            5.9         0.10             2.2      0.062
# 1596            6.3         0.13             2.3      0.076
# 1597            5.9         0.12             2.0      0.075
# 1598            6.0         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# ...

# %%
df.shape
# Out:
# (1599, 11)

# %%
df_new.shape
# Out:
# (1458, 11)
